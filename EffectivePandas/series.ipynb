# %%
import pandas as pd
url = 'https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip'
df = pd.read_csv(url)
city_mpg = df.city08
highway_mpg = df.highway08

df.shape
# Out:
# /var/folders/w0/rm77497502gc451c9d0203y40000gn/T/ipykernel_4654/2498278535.py:3: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
# (41144, 83)

# %%
df.tail(100)
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 41044  14.330870         0.0        0.0        0.0      21      0.0        0
# 41045  27.467500         0.0        0.0        0.0      11      0.0        0
# 41046  14.330870         0.0        0.0        0.0      21      0.0        0
# 41047  12.677308         0.0        0.0        0.0      23      0.0        0
# 41048  14.330870         0.0        0.0        0.0      21      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 41139  14.982273         0.0        0.0        0.0      19      0.0        0
# 41140  14.330870         0.0        0.0        0.0      20      0.0        0
# 41141  15.695714         0.0        0.0        0.0      18      0.0        0
# 41142  15.695714         0.0        0.0        0.0      18      0.0        0
# 41143  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
series = {
    'index':[0, 1, 2, 3],
    'data':[145, 142, 38, 13],
    'name':'songs'
    }

series['data'][1]
# Out:
# 142
